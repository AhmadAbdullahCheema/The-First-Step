# %% [markdown]
# # Data Preprocessing Steps

# %% [markdown]
# 1. Reading Data
# 2. Exploring Data / Data Insight
# 3. Cleansing Data
# 4. Outlier Detection and Removing
# 5. Data Transformation (Normalize Data / Rescale Data)
# 6. Categorical into Numerical
# 7. Dimensionality Reduction(PCA)
# 8. Handling Imbalanced Data
# 9. Feature Selection
# 10. Data Splitting

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
color = sns.color_palette()

import numpy as np 
import pandas as pd

# %% [markdown]
# # 1: Reading Data

# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

# %%
data.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
data.head(30)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 1   15.0          8         350.0        165    3693          11.5
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
# 11  14.0          8         340.0        160    3609           8.0
# 12  15.0          8         400.0        150    3761           9.5
# ...

# %%
data.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
data.shape
# Out:
# (398, 9)

# %%
data.tail(20)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 378  38.0          4         105.0         63    2125          14.7
# 379  36.0          4          98.0         70    2125          17.3
# 380  36.0          4         120.0         88    2160          14.5
# 381  36.0          4         107.0         75    2205          14.5
# 382  34.0          4         108.0         70    2245          16.9
# 383  38.0          4          91.0         67    1965          15.0
# 384  32.0          4          91.0         67    1965          15.7
# 385  38.0          4          91.0         67    1995          16.2
# 386  25.0          6         181.0        110    2945          16.4
# 387  38.0          6         262.0         85    3015          17.0
# 388  26.0          4         156.0         92    2585          14.5
# 389  22.0          6         232.0        112    2835          14.7
# 390  32.0          4         144.0         96    2665          13.9
# ...

# %%
data.sample()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 282  22.3          4         140.0         88    2890          17.3
#
#      model year  origin         car name
# 282          79       1  ford fairmont 4

# %%
data.sample(30)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 109  21.0          4         140.0         72    2401          19.5
# 118  24.0          4         116.0         75    2158          15.5
# 373  24.0          4         140.0         92    2865          16.4
# 318  29.8          4         134.0         90    2711          15.5
# 314  26.4          4         140.0         88    2870          18.1
# 345  35.1          4          81.0         60    1760          16.1
# 30   28.0          4         140.0         90    2264          15.5
# 126  21.0          6         200.0          ?    2875          17.0
# 41   14.0          8         318.0        150    4096          13.0
# 208  13.0          8         318.0        150    3940          13.2
# 286  17.6          8         302.0        129    3725          13.4
# 311  32.1          4          98.0         70    2120          15.5
# 389  22.0          6         232.0        112    2835          14.7
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# # 2: Data Cleaning

# %% [markdown]
# Handling Missing Values
# -
# - Imputation: Filling missing values with mean.

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# Separate numeric and non-numeric columns
numeric_cols = data.select_dtypes(include=[np.number])
#non_numeric_cols = data.select_dtypes(exclude=[np.number])
nm = pd.DataFrame(numeric_cols)
nm.head(2)
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model year  origin
# 0  18.0          8         307.0    3504          12.0          70       1
# 1  15.0          8         350.0    3693          11.5          70       1

# %%
# Separate numeric and non-numeric columns
#numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])
non_nm = pd.DataFrame(non_numeric_cols)
non_nm.head(2)
# Out:
#   horsepower                   car name
# 0        130  chevrolet chevelle malibu
# 1        165          buick skylark 320

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

grouped_data = data.groupby('cylinders')

print(grouped_data.head())
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 14   24.0          4         113.0         95    2372          15.0
# 15   22.0          6         198.0         95    2833          15.5
# 16   18.0          6         199.0         97    2774          15.5
# 17   21.0          6         200.0         85    2587          16.0
# 18   27.0          4          97.0         88    2130          14.5
# 19   26.0          4          97.0         46    1835          20.5
# 20   25.0          4         110.0         87    2672          17.5
# 21   24.0          4         107.0         90    2430          14.5
# ...

# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

numeric_cols.fillna(numeric_cols.mean(), inplace=True)

data1 = pd.concat([numeric_cols, non_numeric_cols], axis=1)

missing_values = data1.isnull().sum()
print(missing_values)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# weight          0
# acceleration    0
# model year      0
# origin          0
# horsepower      0
# car name        0
# dtype: int64

# %%
data.shape
# Out:
# (398, 9)

# %% [markdown]
# Removal: Deleting rows with missing values.
# -

# %%
data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.shape
# Out:
# (398, 9)

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

data.dropna(inplace=True)

missing_values = data.isnull().sum()
print(missing_values)
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.shape
# Out:
# (398, 9)

# %% [markdown]
# Removing Duplicates
# -

# %%
data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")
data.shape
# Out:
# (398, 9)

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

data.drop_duplicates(inplace=True)

print(data.shape)
# Out:
# (398, 9)

# %% [markdown]
# # 3: Outlier Detection and Removal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
0.25-1.5*0.5
# Out:
# -0.5

# %%
0.75 + 1.5 * 0.5
# Out:
# 1.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

numeric_cols = data.select_dtypes(include=[np.number])

Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]

plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 2)
data_cleaned.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (390, 9)

# %%
data_cleaned.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# # 4. Data Transformation

# %% [markdown]
# Key Differences
# -
# Range of Values:
#
# Normalization: Values are scaled to a fixed range, typically [0, 1].
# Standardization: Values are rescaled to have a mean of 0 and a standard deviation of 1.
# Effect on Distribution:
#
# Normalization: Compresses or stretches the data to fit within the specified range, potentially altering the original distribution.
# Standardization: Preserves the shape of the original distribution but changes the scale.
# Use Cases:
#
# Normalization: Suitable for distance-based algorithms, like k-nearest neighbors and neural networks.
# Standardization: Suitable for algorithms that assume a normal distribution, like linear regression and logistic regression.

# %% [markdown]
# Normalization/Standardization
# -
# - Normalization
# Definition:
# Normalization rescales the data to a fixed range, typically [0, 1] or [-1, 1].

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

print(scaled_data.shape)
print('*' * 60)
print(scaled_data.head())
# Out:
# (398, 9)
# ************************************************************
#         mpg  cylinders  displacement    weight  acceleration  model year  \
# 0  0.239362        1.0      0.617571  0.536150      0.238095         0.0
# 1  0.159574        1.0      0.728682  0.589736      0.208333         0.0
# 2  0.239362        1.0      0.645995  0.516870      0.178571         0.0
# 3  0.186170        1.0      0.609819  0.516019      0.238095         0.0
# 4  0.212766        1.0      0.604651  0.520556      0.148810         0.0
#
#    origin horsepower                   car name
# 0     0.0        130  chevrolet chevelle malibu
# 1     0.0        165          buick skylark 320
# 2     0.0        150         plymouth satellite
# 3     0.0        150              amc rebel sst
# 4     0.0        140                ford torino

# %% [markdown]
# Standardization
# -
# Definition:
# Standardization rescales the data so that it has a mean of 0 and a standard deviation of 1.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

print(scaled_data.shape)
print('*' * 60)
print(scaled_data.head())
# Out:
# (398, 9)
# ************************************************************
#         mpg  cylinders  displacement    weight  acceleration  model year  \
# 0 -0.706439   1.498191      1.090604  0.630870     -1.295498   -1.627426
# 1 -1.090751   1.498191      1.503514  0.854333     -1.477038   -1.627426
# 2 -0.706439   1.498191      1.196232  0.550470     -1.658577   -1.627426
# 3 -0.962647   1.498191      1.061796  0.546923     -1.295498   -1.627426
# 4 -0.834543   1.498191      1.042591  0.565841     -1.840117   -1.627426
#
#      origin horsepower                   car name
# 0 -0.715145        130  chevrolet chevelle malibu
# 1 -0.715145        165          buick skylark 320
# 2 -0.715145        150         plymouth satellite
# 3 -0.715145        150              amc rebel sst
# 4 -0.715145        140                ford torino

# %% [markdown]
# # 5: One-Hot Encoding

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")
data.head(2)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320

# %%
data["car name"].unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
 data.groupby('cylinders')

# %%
print(data.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(data, columns=cat_features)

print(data1.head())
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model year  origin  \
# 0  18.0          8         307.0    3504          12.0          70       1
# 1  15.0          8         350.0    3693          11.5          70       1
# 2  18.0          8         318.0    3436          11.0          70       1
# 3  16.0          8         304.0    3433          12.0          70       1
# 4  17.0          8         302.0    3449          10.5          70       1
#
#    horsepower_100  horsepower_102  horsepower_103  ...  \
# 0           False           False           False  ...
# 1           False           False           False  ...
# 2           False           False           False  ...
# 3           False           False           False  ...
# 4           False           False           False  ...
#
#    car name_volvo 145e (sw)  car name_volvo 244dl  car name_volvo 245  \
# 0                     False                 False               False
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Columns: 406 entries, mpg to car name_vw rabbit custom
# dtypes: bool(399), float64(3), int64(4)
# memory usage: 177.0 KB

# %%
cat_features
# Out:
# ['horsepower', 'car name']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(data, columns=cat_features)

scaled_data = pd.concat([data, data1], axis=1)

print(scaled_data.shape)
print('*' * 70)
print(scaled_data.head())
# Out:
# (398, 415)
# **********************************************************************
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name   mpg  ...  car name_volvo 145e (sw)  \
# 0       1  chevrolet chevelle malibu  18.0  ...                     False
# 1       1          buick skylark 320  15.0  ...                     False
# 2       1         plymouth satellite  18.0  ...                     False
# 3       1              amc rebel sst  16.0  ...                     False
# ...

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
scaled_data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name', 'mpg',
#        ...
#        'car name_volvo 145e (sw)', 'car name_volvo 244dl',
#        'car name_volvo 245', 'car name_volvo 264gl', 'car name_volvo diesel',
#        'car name_vw dasher (diesel)', 'car name_vw pickup',
#        'car name_vw rabbit', 'car name_vw rabbit c (diesel)',
#        'car name_vw rabbit custom'],
#       dtype='object', length=415)

# %%
data1.head()
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model year  origin  \
# 0  18.0          8         307.0    3504          12.0          70       1
# 1  15.0          8         350.0    3693          11.5          70       1
# 2  18.0          8         318.0    3436          11.0          70       1
# 3  16.0          8         304.0    3433          12.0          70       1
# 4  17.0          8         302.0    3449          10.5          70       1
#
#    horsepower_100  horsepower_102  horsepower_103  ...  \
# 0           False           False           False  ...
# 1           False           False           False  ...
# 2           False           False           False  ...
# 3           False           False           False  ...
# 4           False           False           False  ...
#
#    car name_volvo 145e (sw)  car name_volvo 244dl  car name_volvo 245  \
# 0                     False                 False               False
# ...

# %% [markdown]
# # 6: Data Reduction

# %% [markdown]
# Dimensionality Reduction
# -
# PCA (Principal Component Analysis)

# %%
scaled_data.shape
# Out:
# (398, 415)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

pca = PCA(n_components=15)
data_pca = pca.fit_transform(data)

print(data_pca.shape)
print(data_pca[:5])

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[numeric_features[0]], data[numeric_features[1]], alpha=0.5)
plt.title('Original Data')
plt.xlabel(numeric_features[0])
plt.ylabel(numeric_features[1])

pca = PCA(n_components=2)
data_pca = pca.fit_transform(data)

plt.subplot(1, 2, 2)
plt.scatter(data_pca[:, 0], data_pca[:, 1], alpha=0.5)
plt.title('PCA Transformed Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.tight_layout()
plt.show()
# Out:
# (398, 15)
# [[ 2.69635167e+00 -1.04476979e+00 -1.27965345e-01 -4.14787214e-01
#    7.35009606e-01 -2.53484631e-01 -7.71717666e-02 -1.22543496e-01
#   -6.05302765e-03 -1.01116117e-01 -6.03965278e-02 -6.31359578e-02
#   -2.70416806e-01  8.75963231e-02 -8.46784193e-02]
#  [ 3.19116883e+00 -1.07354710e+00 -2.29862074e-01 -3.15622664e-01
#    5.01024684e-01 -1.16774904e-01 -1.74914343e-01 -1.24736017e-01
#    4.76744181e-02 -1.14534292e-01 -7.69461139e-02  4.21491049e-02
#   -3.31651468e-02 -5.62363718e-02 -2.17092801e-02]
#  [ 2.83643702e+00 -1.19040303e+00 -4.36718342e-01 -5.70959916e-01
#    7.85891966e-01 -3.54616472e-01  5.42887408e-01  4.28353563e-01
#    9.87104157e-02  1.40832302e-01  1.89237668e-01  6.95461095e-02
#    2.36394311e-01 -4.36108109e-02  1.17655021e-03]
#  [ 2.78386155e+00 -1.10941394e+00 -8.23474280e-02 -4.12015018e-01
#    6.04024823e-01 -4.88490459e-01  5.63762882e-01  4.40758548e-01
#    1.02648865e-01  1.48856939e-01  1.67393364e-01  6.38875617e-02
# ...

# %%
type(data_pca)
# Out:
# numpy.ndarray

# %%
data_pca.ndim
# Out:
# 2

# %%
data_pca.shape
# Out:
# (398, 2)

# %% [markdown]
# # 7: Handling Imbalanced Data
#
# - Resampling Techniques
# - Oversampling

# %%
data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")
print(data['car name'].value_counts(normalize=True))
# Out:
# car name
# ford pinto             0.015075
# ford maverick          0.012563
# amc matador            0.012563
# toyota corolla         0.012563
# amc hornet             0.010050
#                          ...
# amc concord dl         0.002513
# volkswagen rabbit l    0.002513
# mazda glc custom l     0.002513
# mazda glc custom       0.002513
# chevy s-10             0.002513
# Name: proportion, Length: 305, dtype: float64

# %%
data.shape
# Out:
# (398, 9)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

# Ensure column name is correctly identified
target_col = 'car name' if 'car name' in data.columns else data.columns[-1]
X = data.drop(columns=[target_col])
y = data[target_col]

if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=[target_col])], axis=1)
print(data_resampled.head())
# Out:
# (398, 405) (398,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 32
#      29 print(X.shape, y.shape)
#      31 smote = SMOTE(random_state=42)
# ---> 32 X_resampled, y_resampled = smote.fit_resample(X, y)
#      34 data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=[target_col])], axis=1)
#      35 print(data_resampled.head())
#
# File ~\anaconda3\envs\ahmad\Lib\site-packages\imblearn\base.py:202, in BaseSampler.fit_resample(self, X, y, **params)
#     181 def fit_resample(self, X, y, **params):
#     182     """Resample the dataset.
#     183
#     184     Parameters
#    (...)
#     200         The corresponding label of `X_resampled`.
#     201     """
# --> 202     return super().fit_resample(X, y, **params)
#
# ...

# %%
print(data['origin'].value_counts(normalize=True))
# Out:
# origin
# -0.715145    0.625628
#  1.781589    0.198492
#  0.533222    0.175879
# Name: proportion, dtype: float64

# %%
data_resampled.shape
# Out:
# (2, 406)

# %% [markdown]
# Undersampling
# -

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
from imblearn.under_sampling import RandomUnderSampler

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

data.fillna(data.mean(numeric_only=True), inplace=True)

cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

# Correct target column selection
target_col = 'car name' if 'car name' in data.columns else data.columns[-1]

X = data.drop(columns=[target_col])
y = data[target_col]

if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)

rus = RandomUnderSampler()
X_resampled, y_resampled = rus.fit_resample(X, y)

data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=[target_col])], axis=1)

print(data_resampled.head())
# Out:
# (398, 405) (398,)
#           mpg  cylinders  displacement    weight  acceleration  model year  \
# 384  1.087017  -0.856321     -0.983552 -1.188758      0.047894    1.621983
# 293  1.074207  -0.856321     -1.002757 -1.236052     -0.569341    0.809631
#
#        origin  horsepower_100  horsepower_102  horsepower_103  ...  \
# 384  1.781589           False           False           False  ...
# 293  0.533222           False           False           False  ...
#
#      car name_volvo 145e (sw)  car name_volvo 244dl  car name_volvo 245  \
# 384                     False                 False               False
# 293                     False                 False               False
#
#      car name_volvo 264gl  car name_volvo diesel  car name_vw dasher (diesel)  \
# 384                 False                  False                        False
# 293                 False                  False                        False
#
# ...

# %%
print(data['origin'].value_counts(normalize=True))
# Out:
# origin
# -0.715145    0.625628
#  1.781589    0.198492
#  0.533222    0.175879
# Name: proportion, dtype: float64

# %%
data_resampled.shape
# Out:
# (2, 406)

# %% [markdown]
# # Target Encoder

# %%
import pandas as pd
from category_encoders import TargetEncoder

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")
cat_features = ['car name'] if 'car name' in data.columns else [data.columns[-1]]

target_encoder = TargetEncoder(cols=cat_features)

target_encoded = target_encoder.fit_transform(data[cat_features], data['mpg'])

print(target_encoded.head())
# Out:
#     car name
# 0  22.661399
# 1  22.406755
# 2  22.797080
# 3  22.536863
# 4  22.666972

# %% [markdown]
# # 8: Splitting Data

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

data = pd.read_csv(r"C:\Users\Administrator\OneDrive\Desktop\auto-mpg.csv")

target_col = 'car name' if 'car name' in data.columns else data.columns[-1]

X = data.drop(columns=[target_col])
y = data[target_col]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((278, 8), (120, 8), (278,), (120,))
